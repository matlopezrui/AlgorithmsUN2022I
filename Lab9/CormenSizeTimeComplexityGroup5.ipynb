# %% [markdown]
# <a href="https://colab.research.google.com/github/matlopezrui/AlgorithmsUN2022I/blob/main/CormenSizeTimeComplexityGroup5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.(10  nanoseconds by instruction)
#
# Asuuming that you can execute a 100 million instructions $100 \times 10^6$ every second, i.e. each instrcution takes 10 nanoseconds, 10 $\eta s  = 10^{-8} s $. If you have algorithms take $\bf{ Time\ Complexity}$ steps to solve a poblem of size $n$ as specified in column one. What is the size of the largest porblem that you can solve in the time specified in row one?
#
# $$
# \begin{array}{|c|c|c|c|c|c|c|c|}
#  \hline
#  \bf{ Time\ Complexity} & Second  & Minute  & Hour & Day & Year & Century & Mileniun  \\
#   \hline\\
# \lg(n) &   2^{10^{8}}  & 2^{60 \times 10^{8}}  & 2^{3600 \times 10^{8}} & 2^{86400 \times 10^{8}}  & 2^{31536000 \times 10^{8}} & 2^{3153600000 \times 10^{8}} & 2^{31536000000 \times 10^{8}} \\
#    \hline\\
# \lg^2(n) & 2^{10^{4}}   & 2^{10^{4} \times \sqrt{60}}  & 2^{10^{4} \times 60} & 2^{10^{4} \times \sqrt{86400}}  & 2^{10^{4} \times \sqrt{31536000}}  &2^{10^{4} \times \sqrt{3153600000}}  & 2^{10^{4} \times \sqrt{31536000000}}  \\
#    \hline\\
# \sqrt{n} & 10^{16}   & {3600 \times 10^{16}}  & {12960000 \times 10^{16}} & {7464960000 \times 10^{16}} &  {9.94519296\times 10^{14} \times 10^{16}} & {9.94519296\times 10^{18} \times 10^{16}} &  {9.94519296\times 10^{20} \times 10^{16}}\\
#  \hline
#  n & 10^{8}   & 60\times10^{8}   & 3600\times10^{8}  & 86400\times10^{8}  & 31536000\times10^{8} & 3153600000\times10^{8}  & 31536000000\times10^{8}  \\
#  \hline
#  n\lg(n) & 4523071  & 216677120   & 10800938300  & 228957337705 & 68610956750570 & 6016277763015247 & 5075142713362522112 \\
#  \hline
#  n^2 & 10000   & 77459  & 600000 & 2939387 & 561569223 & 5615692230 & 1775837830 \\
#  \hline
#   n^3 &  100\sqrt[3]{10^2}  & 391\sqrt[3]{10^2}  & 1532\sqrt[3]{10^2}  & 4420\sqrt[3]{10^2}  & 31593\sqrt[3]{10^2}  & 146645\sqrt[3]{10^2} & 315938\sqrt[3]{10^2} \\
#  \hline
#   n^4 & 100    & 278  & 774 & 1714 & 7493 & 23697 &  42140\\
#  \hline
#   2^n &  8lg_2(10) & lg_2(60 \times 10^{8})   & lg_2(3600 \times 10^{8})  & lg_2(86400 \times 10^{8})  & lg_2(31536000 \times 10^{8})  & lg_2(3153600000 \times 10^{8})  & lg_2(31536000000 \times 10^{8}) \\
#  \hline
#  n! &  11  & 12  & 14 & 15 & 17 & 19 & 21 \\
#  \hline
#  n^n & 8   & 9 & 11 & 11 & 13 & 14 & 16 \\
#  \hline
# \end{array}
# $$

# %% [markdown]
# # Time Complexity ln(n)
#
#
# second:
# $$
#   lg(n) × 2^{10^{-8}}s ≤ 1s  \\
#   lg(n) ≤ 1 \times 10^{8}   \\
#   2^{lg(n)} ≤ 2^{10^{8}}    \\
#   n ≤ 2^{10^{8}}            \\
# $$
# minute:
# $$
#   lg(n) \times 10^{-8}s ≤ 60s \\
#   lg(n) ≤ 60 \times 10^{8}    \\
#   2^{lg(n)} ≤ 2^{60 \times 10^{8}} \\
#   n ≤ 2^{60 \times 10^{8}}         \\
# $$
# hour:
# $$
#   lg(n) \times 10^{-8}s ≤ 3600s \\
#   lg(n) ≤ 3600 \times  10^{8}  \\
#   2^{lg(n)} ≤ 2^{3.6 \times 10^{11}} \\
#   n ≤ 2^{3.6 \times 10^{11}}    \\
# $$
# day:
# $$
#   lg(n) \times 10^{-8}s ≤ 86400s \\
#   lg(n) ≤ 86400 \times 10^{8}    \\
#   2^{lg(n)} ≤ 2^{8.64 \times 10^{12}} \\
#   n ≤ 2^{8.64 \times 10^{12}}        \\
# $$
# year:
# $$
#   lg(n) \times 10^{-8}s ≤ 31536000s \\
#   lg(n) ≤ 31536000 \times 10^{8}    \\
#   2^{lg(n)} ≤ 2^{3.1536 \times 10^15} \\
#   n ≤ 2^{3.1536 \times 10^{15}}
# $$
# century:
# $$
#   lg(n) \times 10^{-8}s ≤ 3153600000s \\
#   lg(n) ≤ 3153600000 \times 10^{8}    \\
#   2^{lg(n)} ≤ 2^{3.1536 \times 10^{17}}\\
#   n ≤ 2^{3.1536 \times 10^{17}}
# $$
# mileniun:
# $$
#   lg(n) \times 10^{-8}s ≤ 3153600000s \\
#   lg(n) ≤ 3153600000 \times 10^{8}    \\
#   2^{lg(n)} ≤ 2^{3.1536 \times 10^{18}}\\
#   n ≤ 2^{3.1536 \times 10^{18}}
# $$

# %% [markdown]
# # Time Complexity ln^2(n)
#
#
# second:
# $$
#   lg^{2}(n) × 2^{10^{-8}}s ≤ 1s  \\
#   lg(n) ≤ \sqrt{1 \times 10^{8}}   \\
#   2^{lg(n)} ≤ 2^\sqrt{10^{8}}    \\
#   n ≤ 2^{10^{4}}            \\
#   n ≤ 2^{10000}
# $$
# minute:
# $$
#   lg^{2}(n) \times 10^{-8}s ≤ 60s \\
#   lg(n) ≤ \sqrt{60 \times 10^{8}}    \\
#   2^{lg(n)} ≤ 2^\sqrt{60 \times 10^{8}} \\
#   n ≤ 2^\sqrt{60 \times 10^{8}}         \\
#   n ≤ 2^{77460}
# $$
# hour:
# $$
#   lg^{2}(n) \times 10^{8}s ≤ 3600s \\
#   lg(n) ≤ \sqrt{3600 \times  10^{8}}  \\
#   2^{lg(n)} ≤ 2^\sqrt{3.6 \times 10^{11}} \\
#   n ≤ 2^\sqrt{3.6 \times 10^{11}} \\
#   n ≤ 2^{600000}
# $$
# day:
# $$
#   lg^{2}(n) \times 10^{-8}s ≤ 86400s \\
#   lg(n) ≤ \sqrt{86400 \times 10^{8}}    \\
#   2^{lg(n)} ≤ 2^\sqrt{8.64 \times 10^{12}} \\
#   n ≤ 2^\sqrt{8.64 \times 10^{12}}        \\
#   n≤ 2^{2939388}
# $$
# year:
# $$
#   lg^{2}(n) \times 10^{-8}s ≤ 31536000s \\
#   lg(n) ≤ \sqrt{31536000 \times 10^{8}}    \\
#   2^{lg(n)} ≤ 2^\sqrt{3.1536 \times 10^15} \\
#   n ≤ 2^\sqrt{3.1536 \times 10^{15}} \\
#   n ≤ 2^{56156923}
# $$
# century:
# $$
#   lg^{2}(n) \times 10^{-8}s ≤ 3153600000s \\
#   lg(n) ≤ \sqrt{3153600000 \times 10^{8}}    \\
#   2^{lg(n)} ≤ 2^\sqrt{3.1536 \times 10^{17}}\\
#   n ≤ 2^\sqrt{3.1536 \times 10^{17}} \\
#   n ≤ 2^{561569230}
# $$
# mileniun:
# $$
#   lg^{2}(n) \times 10^{-8}s ≤ 3153600000s \\
#   lg(n) ≤ \sqrt{3153600000 \times 10^{8}}    \\
#   2^{lg(n)} ≤ 2^\sqrt{3.1536 \times 10^{18}}\\
#   n ≤ 2^\sqrt{3.1536 \times 10^{16}} \\
#   n ≤ 2^{17758378304}
# $$

# %%
import math
i = 10**8
print("Second 2^{",round(math.sqrt(i)),"}")
print("Minute 2^{",round(math.sqrt(60*i)),"}")
print("Hour 2^{",round(math.sqrt(60*60*i)),"}")
print("Day 2^{",round(math.sqrt(24*60*60*i)),"}")
print("Year 2^{",round(math.sqrt(365*24*60*60*i)),"}")
print("Century 2^{",round(math.sqrt(100*365*24*60*60*i)),"}")
print("Mileniun 2^{",round(math.sqrt(1000*100*365*24*60*60*i)),"}")
# Out:
# Second 2^{ 10000 }
# Minute 2^{ 77460 }
# Hour 2^{ 600000 }
# Day 2^{ 2939388 }
# Year 2^{ 56156923 }
# Century 2^{ 561569230 }
# Mileniun 2^{ 17758378304 }

# %% [markdown]
# $$
# Time Complexity \sqrt{(n)}
# $$
#
# second:
# $$
#   \sqrt{n} × 2^{10^{-8}}s ≤ 1s  \\
#   \sqrt{n} ≤ 10^{8}   \\
#   n ≤ 10^{16}
# $$
# minute:
# $$
#   \sqrt{n} × 2^{10^{-8}}s ≤ 60s  \\
#   \sqrt{n} ≤ 60 \times 10^{8}   \\
#   n ≤ 3.6 \times 10^{19}
# $$
# hour:
# $$
#   \sqrt{n} \times 10^{8}s ≤ 3600s \\
#   \sqrt{n} ≤ {3600 \times  10^{8}}  \\
#   n ≤ 1.296 \times 10^{23}
# $$
# day:
# $$
#   \sqrt{n} \times 10^{8}s ≤ 86400s \\
#   \sqrt{n} ≤ {86400 \times  10^{8}}  \\
#   n ≤ 7.46496 \times 10^{25}
# $$
# year:
# $$
#   \sqrt{n} \times 10^{8}s ≤ 3153600s \\
#   \sqrt{n} ≤ {3153600 \times  10^{8}}  \\
#   n ≤ 9.94519296 \times 10^{30}
# $$
# century:
# $$
#   \sqrt{n} \times 10^{8}s ≤ 315360000s \\
#   \sqrt{n} ≤ {315360000 \times  10^{8}}  \\
#   n ≤ 9.94519296 \times 10^{34}
# $$
# mileniun:
# $$
#   \sqrt{n} \times 10^{8}s ≤ 3153600000s \\
#   \sqrt{n} ≤ {3153600000 \times  10^{8}}  \\
#   n ≤ 9.94519296 \times 10^{40}
# $$

# %%
import math
i = 10**8 
print("Second ", "{:.8E}".format(math.pow(i,2)))
print("Minute  ","{:.8E}".format(math.pow(60*i,2)))
print("Hour ","{:.8E}".format(math.pow(60*60*i,2)))
print("Day ","{:.8E}".format(math.pow(24*60*60*i,2)))
print("Year ","{:.8E}".format(math.pow(365*24*60*60*i,2)))
print("Century ","{:.8E}".format(math.pow(100*365*24*60*60*i,2)))
print("Mileniun  ","{:.8E}".format(math.pow(1000*100*365*24*60*60*i,2)))
# Out:
# Second  1.00000000E+16
# Minute   3.60000000E+19
# Hour  1.29600000E+23
# Day  7.46496000E+25
# Year  9.94519296E+30
# Century  9.94519296E+34
# Mileniun   9.94519296E+40

# %% [markdown]
# $$
# Time Complexity \\   n
# $$
#
# second:
# $$
#   {n} × 2^{10^{-8}}s ≤ 1s  \\
#   n ≤ 10^{8}
# $$
# minute:
# $$
#   {n} × 2^{10^{-8}}s ≤ 60s  \\
#   n ≤ 60 \times 10^{8}
# $$
# hour:
# $$
#   {n} \times 10^{8}s ≤ 3600s \\
#   n ≤ 3600 \times 10^{11}
# $$
# day:
# $$
#   {n} \times 10^{8}s ≤ 86400s \\
#   n ≤ 8.64 \times 10^{12}
# $$
# year:
# $$
#   {n} \times 10^{8}s ≤ 31536000s \\
#   n ≤ 31536000 \times 10^{15}
# $$
# century:
# $$
#   {n} \times 10^{8}s ≤ 3153600000s \\
#   n ≤ 31536000000 \times 10^{17}
# $$
# mileniun:
# $$
#   {n} \times 10^{8}s ≤ 315360000000s \\
#   n ≤ 315360000000 \times 10^{20}
# $$

# %%
import math
i = 10**8 
print("Second ", "{:.8E}".format(i))
print("Minute  ","{:.8E}".format(60*i))
print("Hour ","{:.8E}".format(60*60*i))
print("Day ","{:.8E}".format(24*60*60*i))
print("Year ","{:.8E}".format(365*24*60*60*i))
print("Century ","{:.8E}".format(100*365*24*60*60*i))
print("Mileniun  ","{:.8E}".format(1000*100*365*24*60*60*i))
# Out:
# Second  1.00000000E+08
# Minute   6.00000000E+09
# Hour  3.60000000E+11
# Day  8.64000000E+12
# Year  3.15360000E+15
# Century  3.15360000E+17
# Mileniun   3.15360000E+20

# %% [markdown]
# $$
# Time Complexity \\   n \ log(n)
# $$
#
# second:
# $$
#   n\ lg(n) × 2^{10^{-8}}s ≤ 1s  \\
#   n\ lg(n) ≤ 10^{8}
# $$
# minute:
# $$
#   n\ lg(n) × 2^{10^{-8}}s ≤ 60s  \\
#   n\ lg(n) ≤ 60 \times 10^{8}
# $$
# hour:
# $$
#   n\ lg(n) \times 10^{8}s ≤ 3600s \\
#   n\ lg(n) ≤ 3600 \times 10^{8}
# $$
# day:
# $$
#   n\ lg(n) \times 10^{8}s ≤ 86400s \\
#   n\ lg(n) ≤ 8.64 \times 10^{12}
# $$
# year:
# $$
#   n\ lg(n) \times 10^{8}s ≤ 31536000s \\
#   n\ lg(n) ≤ 31536000 \times 10^{8}
# $$
# century:
# $$
#   n\ lg(n) \times 10^{8}s ≤ 3153600000s \\
#   n\ lg(n) ≤ 31536000000 \times 10^{8}
# $$
# mileniun:
# $$
#   n\ lg(n) \times 10^{8}s ≤ 315360000000s \\
#   n\ lg(n) ≤ 315360000000 \times 10^{8}
# $$

# %%
import math
def f(n):
  return n*math.log2(n)


def find(f,v):
  l = 1
  r = v
  while True:
    m = int((l+r)/2)
    if ((f(m+1) > v) and (f(m) <= v) ) or (l == m) or  (r == m):
      return int(m)   
    elif f(m) < v:
      l = m
    else: 
      r = m
      
i = 10**8 
print("Second ", find(f,i)," = ", "{:.8E}".format(find(f,i )))
print("Minute  ",find(f,60*i)," = ", "{:.8E}".format(find(f,60*i )))
print("Hour ",find(f,60*60*i)," = ", "{:.8E}".format(find(f,60*60*i )))
print("Day ",find(f,24*60*60*i )," = ", "{:.8E}".format(find(f,24*60*60*i )) )
print("Year ",find(f,365*24*60*60*i )," = ", "{:.8E}".format(find(f,365*24*60*60*i )) )
print("Century ",find(f,100*365*24*60*60*i )," = ", "{:.8E}".format(find(f,100*365*24*60*60*i )) )
print("Mileniun ",find(f,1000*100*365*24*60*60*i )," = ", "{:.8E}".format(find(f,1000*100*365*24*60*60*i )) )
# Out:
# Second  4523071  =  4.52307100E+06
# Minute   216677120  =  2.16677120E+08
# Hour  10800938300  =  1.08009383E+10
# Day  228957337705  =  2.28957338E+11
# Year  68610956750570  =  6.86109568E+13
# Century  6016277763015247  =  6.01627776E+15
# Mileniun  5075142713362522112  =  5.07514271E+18

# %% [markdown]
# $$
# Time Complexity \\   n^{2}
# $$
#
# second:
# $$
#   {n}^{2} × 2^{10^{-8}}s ≤ 1s  \\
#   n^{2} ≤ 10^{8} \\
#   n ≤ 1000
# $$
# minute:
# $$
#   {n}^{2} × 2^{10^{-8}}s ≤ 60s  \\
#   n^{2} ≤ 60 \times 10^{8} \\
#   n ≤ 77460
# $$
# hour:
# $$
#   {n}^{2} \times 10^{-8}s ≤ 3600s \\
#   n^{2} ≤ 3600 \times 10^{11} \\
#   n ≤ 600000
# $$
# day:
# $$
#   {n}^{2} \times 10^{-8}s ≤ 86400s \\
#   n^{2} ≤ 8.64 \times 10^{12} \\
#   n ≤ 2939388
# $$
# year:
# $$
#   {n}^{2} \times 10^{-8}s ≤ 31536000s \\
#   n^{2} ≤ 31536000 \times 10^{15} \\
#   n ≤ 56156923
# $$
# century:
# $$
#   {n}^{2} \times 10^{-8}s ≤ 3153600000s \\
#   n^{2} ≤ 31536000000 \times 10^{17} \\
#   n ≤ 561569230
# $$
# mileniun:
# $$
#   {n}^2 \times 10^{-8}s ≤ 315360000000s \\
#   n^2 ≤ 315360000000 \times 10^{20} \\
#   n ≤ 17758378304
# $$

# %%
import math
i = 10**8
print("Second ",round(math.sqrt(i )))
print("Minute  ",round(math.sqrt(60*i )))
print("Hour ",round(math.sqrt(60*60*i )))
print("Day ",round(math.sqrt(24*60*60*i )))
print("Year ",round(math.sqrt(365*24*60*60*i )))
print("Century ",round(math.sqrt(100*365*24*60*60*i )))
print("Mileniun ",round(math.sqrt(1000*100*365*24*60*60*i )))
# Out:
# Second  10000
# Minute   77460
# Hour  600000
# Day  2939388
# Year  56156923
# Century  561569230
# Mileniun  17758378304

# %% [markdown]
# $$
# Time Complexity \\   n^{3}
# $$
#
# second:
# $$
#   {n}^{3} × 2^{10^{-8}}s ≤ 1s  \\
#   n^{3} ≤ 10^{8} \\
#   n ≤ 464
# $$
# minute:
# $$
#   {n}^{3} × 2^{10^{-8}}s ≤ 60s  \\
#   n^{3} ≤ 60 \times 10^{8} \\
#   n ≤ 1817
# $$
# hour:
# $$
#   {n}^{3} \times 10^{-8}s ≤ 3600s \\
#   n^{3} ≤ 3600 \times 10^{11} \\
#   n ≤ 7114
# $$
# day:
# $$
#   {n}^{3} \times 10^{-8}s ≤ 86400s \\
#   n^{3} ≤ 8.64 \times 10^{12} \\
#   n ≤ 20520
# $$
# year:
# $$
#   {n}^{3} \times 10^{-8}s ≤ 31536000s \\
#   n^{3} ≤ 31536000 \times 10^{15} \\
#   n ≤ 146646
# $$
# century:
# $$
#   {n}^{3} \times 10^{-8}s ≤ 3153600000s \\
#   n^{3} ≤ 31536000000 \times 10^{17} \\
#   n ≤ 680668
# $$
# mileniun:
# $$
#   {n}^3 \times 10^{-8}s ≤ 315360000000s \\
#   n^3 ≤ 315360000000 \times 10^{20} \\
#   n ≤ 6806683
# $$

# %%
import math
i = 10**8
print("Second ",round(math.pow(i ,1/3)))
print("Minute  ",round(math.pow(60*i ,1/3)))
print("Hour ",round(math.pow(60*60*i ,1/3)))
print("Day ",round(math.pow(24*60*60*i ,1/3)))
print("Year ",round(math.pow(365*24*60*60*i ,1/3)))
print("Century ",round(math.pow(100*365*24*60*60*i ,1/3)))
print("Mileniun ",round(math.pow(1000*100*365*24*60*60*i ,1/3)))
# Out:
# Second  464
# Minute   1817
# Hour  7114
# Day  20520
# Year  146646
# Century  680668
# Mileniun  6806683

# %% [markdown]
# $$
# Time Complexity \\   n^{4}
# $$
#
# second:
# $$
#   {n}^{4} × 2^{10^{-8}}s ≤ 1s  \\
#   n^{4} ≤ 10^{8} \\
#   n ≤ 100
# $$
# minute:
# $$
#   {n}^{4} × 2^{10^{-8}}s ≤ 60s  \\
#   n^{4} ≤ 60 \times 10^{8} \\
#   n ≤ 278
# $$
# hour:
# $$
#   {n}^{4} \times 10^{-8}s ≤ 3600s \\
#   n^{4} ≤ 3600 \times 10^{8} \\
#   n ≤ 775
# $$
# day:
# $$
#   {n}^{4} \times 10^{-8}s ≤ 86400s \\
#   n^{4} ≤ 8.64 \times 10^{12} \\
#   n ≤ 1714
# $$
# year:
# $$
#   {n}^{4} \times 10^{-8}s ≤ 31536000s \\
#   n^{4} ≤ 31536000 \times 10^{8} \\
#   n ≤ 7494
# $$
# century:
# $$
#   {n}^{4} \times 10^{-8}s ≤ 3153600000s \\
#   n^{4} ≤ 31536000000 \times 10^{8} \\
#   n ≤ 23697
# $$
# mileniun:
# $$
#   {n}^4 \times 10^{-8}s ≤ 315360000000s \\
#   n^4 ≤ 315360000000 \times 10^{8} \\
#   n ≤ 133261
# $$

# %%
import math
i = 10**8
print("Second ",round(math.pow(i ,1/4)))
print("Minute  ",round(math.pow(60*i ,1/4)))
print("Hour ",round(math.pow(60*60*i ,1/4)))
print("Day ",round(math.pow(24*60*60*i ,1/4)))
print("Year ",round(math.pow(365*24*60*60*i ,1/4)))
print("Century ",round(math.pow(100*365*24*60*60*i ,1/4)))
print("Mileniun ",round(math.pow(1000*100*365*24*60*60*i ,1/4)))
# Out:
# Second  100
# Minute   278
# Hour  775
# Day  1714
# Year  7494
# Century  23697
# Mileniun  133261

# %% [markdown]
# $$
# Time Complexity \\   2^{n}
# $$
#
# second:
# $$
#   {2}^{n} × 2^{10^{-8}}s ≤ 1s  \\
#   2^{n} ≤ 10^{8} \\
#   n ≤ 26
# $$
# minute:
# $$
#   {2}^{n} × 2^{10^{-8}}s ≤ 60s  \\
#   2^{n} ≤ 60 \times 10^{8} \\
#   n ≤ 32
# $$
# hour:
# $$
#   {2}^{n} \times 10^{-8}s ≤ 3600s \\
#   2^{n} ≤ 3600 \times 10^{8} \\
#   n ≤ 38
# $$
# day:
# $$
#   {2}^{n} \times 10^{-8}s ≤ 86400s \\
#   2^{n} ≤ 8.64 \times 10^{12} \\
#   n ≤ 42
# $$
# year:
# $$
#   {2}^{n} \times 10^{-8}s ≤ 31536000s \\
#   2^{n} ≤ 31536000 \times 10^{8} \\
#   n ≤ 51
# $$
# century:
# $$
#   {2}^{n} \times 10^{-8}s ≤ 3153600000s \\
#   2^{n} ≤ 31536000000 \times 10^{-8} \\
#   n ≤ 58
# $$
# mileniun:
# $$
#   {2}^n \times 10^{-8}s ≤ 315360000000s \\
#   2^n ≤ 315360000000 \times 10^{8} \\
#   n ≤ 68
# $$

# %%
import math
i = 10**8
print("Second ",int(math.log2(i )))
print("Minute  ",int(math.log2(60*i )))
print("Hour ",int(math.log2(60*60*i )))
print("Day ",int(math.log2(24*60*60*i )))
print("Year ",int(math.log2(365*24*60*60*i )))
print("Century ",int(math.log2(100*365*24*60*60*i )))
print("Mileniun ",int(math.log2(1000*100*365*24*60*60*i )))
# Out:
# Second  26
# Minute   32
# Hour  38
# Day  42
# Year  51
# Century  58
# Mileniun  68

# %%
import math
def f(n):
  return 2**n

def find(f,v):
  l = 1
  r = 100
  while True:
    m = int((l+r)/2)
    if ((f(m+1) > v) and (f(m) <= v) ) or (l == m)  or (r== m):
      return int(m)
    elif f(m) < v:
      l = m
    else: 
      r = m

i = 10**8
print("Second ", find(f,i))
print("Minute  ",find(f,60*i))
print("Hour ",find(f,60*60*i))
print("Day ",find(f,24*60*60*i))
print("Year ",find(f,365*24*60*60*i))
print("Century ",find(f,100*365*24*60*60*i))
print("Mileniun ",find(f,1000*100*365*24*60*60*i))
# Out:
# Second  26
# Minute   32
# Hour  38
# Day  42
# Year  51
# Century  58
# Mileniun  68

# %% [markdown]
# $$
# Time Complexity \\   n!
# $$
#
# second:
# $$
#   {n!} × 2^{10^{-8}}s ≤ 1s  \\
#   n! ≤ 10^{8}
#   n ≤ 11
# $$
# minute:
# $$
#   {n!} × 2^{10^{-8}}s ≤ 60s  \\
#   n! ≤ 60 \times 10^{8}
#   n ≤ 12
# $$
# hour:
# $$
#   {n!} \times 10^{-8}s ≤ 3600s \\
#   n! ≤ 3600 \times 10^{8}
#   n ≤ 14
# $$
# day:
# $$
#   {n!} \times 10^{-8}s ≤ 86400s \\
#   n! ≤ 8.64 \times 10^{12}
#   n ≤ 15
# $$
# year:
# $$
#   {n!} \times 10^{-8}s ≤ 31536000s \\
#   n! ≤ 31536000 \times 10^{8}
#   n ≤ 17
# $$
# century:
# $$
#   {n!} \times 10^{-8}s ≤ 3153600000s \\
#   n! ≤ 31536000000 \times 10^{8}
#   n ≤ 19
# $$
# mileniun:
# $$
#   {n!} \times 10^{-8}s ≤ 315360000000s \\
#   n! ≤ 315360000000 \times 10^{8}
#   n ≤ 21
# $$

# %%
import math
def f(n):
  return math.factorial(n)

def find(f,v):
  l = 1
  r = 100
  while True:
    m = int((l+r)/2)
    if ((f(m+1) > v) and (f(m) <= v) ) or (l == m) or (r== m):
      return int(m)
    elif f(m) < v:
      l = m
    else: 
      r = m

i = 10**8
print("Second ", find(f,i))
print("Minute  ",find(f,60*i))
print("Hour ",find(f,60*60*i))
print("Day ",find(f,24*60*60*i))
print("Year ",find(f,365*24*60*60*i))
print("Century ",find(f,100*365*24*60*60*i))
print("Mileniun ",find(f,1000*100*365*24*60*60*i))
# Out:
# Second  11
# Minute   12
# Hour  14
# Day  15
# Year  17
# Century  19
# Mileniun  21

# %% [markdown]
# $$
# Time Complexity \\   n^{n}
# $$
#
# second:
# $$
#   {n}^{n} × 2^{10^{-8}}s ≤ 1s  \\
#   n^{n} ≤ 10^{8} \\
#   n ≤ 8
# $$
# minute:
# $$
#   {n}^{n} × 2^{10^{-8}}s ≤ 60s  \\
#   n^{n} ≤ 60 \times 10^{8} \\
#   n ≤ 9
# $$
# hour:
# $$
#   {n}^{n} \times 10^{-8}s ≤ 3600s \\
#   n^{n} ≤ 3600 \times 10^{8} \\
#   n ≤ 11
# $$
# day:
# $$
#   {n}^{n} \times 10^{-8}s ≤ 86400s \\
#   n^{n} ≤ 8.64 \times 10^{12} \\
#   n ≤ 11
# $$
# year:
# $$
#   {n}^{n} \times 10^{-8}s ≤ 31536000s \\
#   n^{n} ≤ 31536000 \times 10^{8} \\
#   n ≤ 13
# $$
# century:
# $$
#   {n}^{n} \times 10^{-8}s ≤ 3153600000s \\
#   n^{n} ≤ 31536000000 \times 10^{8} \\
#   n ≤ 14
# $$
# mileniun:
# $$
#   {n}^n \times 10^{-8}s ≤ 315360000000s \\
#   n^n ≤ 315360000000 \times 10^{8} \\
#   n ≤ 16
# $$

# %%
import math
def f(n):
  return n**n

def find(f,v):
  l = 1
  r = 100
  while True:
    m = int((l+r)/2)
    if ((f(m+1) > v) and (f(m) <= v) ) or (l == m) or (r== m):
      return int(m)
    elif f(m) < v:
      l = m
    else: 
      r = m

i = 10**8
print("Second ", find(f,i))
print("Minute  ",find(f,60*i))
print("Hour ",find(f,60*60*i))
print("Day ",find(f,24*60*60*i))
print("Year ",find(f,365*24*60*60*i))
print("Century ",find(f,100*365*24*60*60*i))
print("Mileniun ",find(f,1000*100*365*24*60*60*i))
# Out:
# Second  8
# Minute   9
# Hour  11
# Day  11
# Year  13
# Century  14
# Mileniun  16
